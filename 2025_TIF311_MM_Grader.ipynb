# %% [markdown]
# <a href="https://colab.research.google.com/github/ipgub/comlib/blob/main/2025_TIF311_MM_Grader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MULTIMEDIA SYSTEMS - MIDTERM RUBRICS**

# %% [markdown]
# ## **PREPARATION**

# %% [markdown]
# ## **PART 1: AUDIO PROCESSING**

# %% [markdown]
# ---
#
# #### **ANALYSIS QUESTIONS 1.1** (Answer in markdown cell below):
#
# 1. What do the peaks in your frequency spectrum represent?
# 2. Identify all the frequencies that appear on your audio signal! How does the sampling rate affect the maximum frequency you can represent?
# 3. If you were to compress this audio signal, which frequency components would be most important to preserve and why?
# 4. Based on your downsampled results, explain what happen when your signal is downsampled to a sampling rate less than twice the highest frequency on the signal?
# 5. Based on the resulting downsampled signal above, identify the frequencies in the downsampled-aliased signal; what are these frequencies? How do they relate to the frequencies in the original signal? You might need to use some of the helper functions to identify these aliased frequencies. Determine the minimum sampling rate where you can still reproduce the audio signal without any aliasing on the downsampled results! Verify this by comparing the spectrum of the downsampled and original signal.

# %% [markdown]
# ***YOUR ANSWERS FOR 1.1***
#
#
# *Write your answers in this space. You may also add code cell if needed to support your analysis*

# %% [markdown]
# ---
#
# #### **ANALYSIS QUESTIONS 1.2** (Answer in markdown cell below):
#
# 1. Explain the relationship between bit depth and audio quality in your results
# 2. What is the theoretical maximum SNR for an 8-bit quantized signal?
# 3. Describe one practical application where 4-bit audio might be acceptable

# %% [markdown]
# ***YOUR ANSWERS FOR 1.2***
#
#
# *Write your answers in this space. You may also add code cell if needed to support your analysis*
#
# ---

# %% [markdown]
# ## **PART 2: SIMPLE TEXT PROCESSING**

# %% [markdown]
# ---
#
# #### **ANALYSIS QUESTIONS 2** (Answer in markdown cell below):
#
# 1. What does the entropy value tell you about the randomness of your data? Compare the entropy of your full name with the entropy of random characters, for example, generated by `generate_text_string()` function. You may need to use separate code cell to demonstrate this.
# 2. Why is H2 typically lower than H1? Explain using your results.
# 3. If your string had uniform distribution, what would the entropy be? Show this by using empirical data and implementation in separate code cell.
# 4. What is the theoretical compression ratio possible for your string? Compare this with the results of your simulation.

# %% [markdown]
# ***YOUR ANSWERS FOR 2***
#
#
# *Write your answers in this space. You may also add code cell if needed to support your analysis*
#
# ---

# %% [markdown]
# ## **PART 3: HUFFMAN CODING**

# %% [markdown]
# #### **ANALYSIS QUESTIONS 3** (Answer in markdown cell below):
# 1. How does your Huffman code's average bits per symbol compare to the entropy?
# 2. Why is Huffman coding optimal for symbol-by-symbol encoding?
# 3. What happens to compression efficiency if characters have uniform probability?
# 4. Under what conditions would Huffman coding perform poorly?

# %% [markdown]
# ***YOUR ANSWERS FOR 3***
#
#
# *Write your answers in this space. You may also add code cell if needed to support your analysis*
#
# ---

# %% [markdown]
# ## **PART 4: ARITHMETIC CODING**

# %% [markdown]
# #### **ANALYSIS QUESTIONS 4** (Answer in markdown cell below):
#
# 1. Why can arithmetic coding achieve better compression than Huffman for some data?
# 2. Explain the significance of the final interval in your encoding! In the simulation, what would your encoded message be?
# 3. What are the practical disadvantages of arithmetic coding compared to Huffman?
# 4. Calculate and explain the bits needed for each encoding method for your 10 characters above!

# %% [markdown]
# ***YOUR ANSWERS FOR 4***
#
#
# *Write your answers in this space. You may also add code cell if needed to support your analysis*
#
# ---

# %% [markdown]
# ## **PART 5: CRC**

# %% [markdown]
# #### **ANALYSIS QUESTIONS 5** (Answer in markdown cell below):
#
# 1. What types of errors can CRC-8 definitely detect?
# 2. What is the probability of undetected error for random corruption?
# 3. Why is CRC preferred over simple parity in real-world applications?
# 4. How would using CRC-16 instead of CRC-8 affect error detection capability?
# 5. Use the available function to encode an 8-bit data generated from your STUDENT_ID using 4-bit generator polynomial $G(x) = x^3 + x + 1$. Verify this using manual computation (long division) using polyomial.

# %% [markdown]
# ***YOUR ANSWERS FOR 5***
#
#
# *Write your answers in this space. You may also add code cell if needed to support your analysis*
#
# ---

# %% [markdown]
# ## **PART 6: HAMMING CODE**

# %% [markdown]
# #### **ANALYSIS QUESTIONS 6** (Answer in markdown cell below):
#
# 1. Explain how syndrome calculation identifies the error position!
# 2. What is the Generator Matrix $G$ and its corresponding parity check matrix $H$ for this Hamming code? Verify the results of the parity bit and syndrome calculation in the above simulation by manual calculation using $G$ and $H$, respectively.
# 3. What is the code rate (efficiency) of Hamming(7,4)?
# 4. Can Hamming(7,4) correct all 2-bit errors? Explain why or why not. You may use some examples of your own using the functions provided here to support your arguments.
# 5. Calculate the overhead percentage for error correction in your example

# %% [markdown]
# ***YOUR ANSWERS FOR 6***
#
#
# *Write your answers in this space. You may also add code cell if needed to support your analysis*
#
# ---

# %% [markdown]
# # **RECAP**

# %%
# @title
import ipywidgets as widgets
from IPython.display import display

# Grading weights
grading_weights = {
    "Full marks. For correct method/implementation and/or correct calculation steps, and correct final answer": 1.0,
    "Partial marks. For correct method/implementation/explanation, but lack of important details": 0.75,
    "Half marks. For partially correct implementation or superficial explanation": 0.5,
    "Lower half marks. For incorrect method/answers OR only quoting problems": 0.35,
    "Null marks. For totally empty answer OR totally unrelated answers/methods": 0.0
}

# Configuration untuk setiap soal
question_config = {
    1: {'subquestions': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'], 'weight': 1},
    2: {'subquestions': ['A', 'B', 'C', 'D'], 'weight': 1},
    3: {'subquestions': ['A', 'B', 'C', 'D'], 'weight': 1},
    4: {'subquestions': ['A', 'B', 'C', 'D'], 'weight': 1},
    5: {'subquestions': ['A', 'B', 'C', 'D', 'E'], 'weight': 1},
    6: {'subquestions': ['A', 'B', 'C', 'D', 'E'], 'weight': 1}
}

def create_grading_dropdowns(question_config):
    """
    Create all grading dropdowns based on configuration

    Args:
        question_config: dict dengan struktur {question_number: {'subquestions': [...], 'weight': ...}}

    Returns:
        dict: Dictionary of all dropdown widgets
    """
    all_dropdowns = {}

    for q_num, config in question_config.items():
        for subq in config['subquestions']:
            qid = f'q{q_num}{subq}'
            all_dropdowns[qid] = widgets.Dropdown(
                options=list(grading_weights.keys()),
                description=f'{qid}:',
                style={'description_width': '30px'},
                layout=widgets.Layout(width='750px')
            )

    return all_dropdowns

def display_dropdowns_by_part(all_dropdowns, question_config):
    """
    Display dropdowns organized by question number (PART)
    """
    for q_num, config in question_config.items():
        # Display section title
        print(f"\n{'='*60}")
        print(f"PART {q_num} Rubrics Evaluation")
        print(f"{'='*60}\n")

        # Display dropdowns for this question
        for subq in config['subquestions']:
            qid = f'q{q_num}{subq}'
            display(all_dropdowns[qid])

def calculate_scores(all_dropdowns, question_config):
    """
    Calculate scores with subtotals per question and grand total
    """
    results = []
    grand_total = 0
    total_possible = 0

    for q_num, config in question_config.items():
        q_weight = config['weight']
        q_subtotal = 0
        q_max = len(config['subquestions']) * q_weight

        results.append(f"\n{'─'*50}")
        results.append(f"PART {q_num}:")
        results.append(f"{'─'*50}")

        for subq in config['subquestions']:
            qid = f'q{q_num}{subq}'
            score = grading_weights[all_dropdowns[qid].value] * q_weight
            q_subtotal += score
            results.append(f"  {qid}: {score:.2f}/{q_weight}")

        results.append(f"  Subtotal Q{q_num}: {q_subtotal:.2f}/{q_max}")

        grand_total += q_subtotal
        total_possible += q_max

    results.append(f"\n{'='*50}")
    results.append(f"GRAND TOTAL: {grand_total:.2f}/{total_possible}")
    results.append(f"{'='*50}")

    return '\n'.join(results)

# Create all dropdowns
all_dropdowns = create_grading_dropdowns(question_config)


# Create calculate button and output
output = widgets.Output()
calculate_button = widgets.Button(
    description="Calculate Total Score",
    button_style='success',
    icon='calculator'
)

def on_calculate_clicked(b):
    with output:
        output.clear_output()
        results = calculate_scores(all_dropdowns, question_config)
        print(results)

calculate_button.on_click(on_calculate_clicked)

print("\n")

# %%
# Display dropdowns organized by part
display_dropdowns_by_part(all_dropdowns, question_config)
# Out:
# ...
# PART 1 Rubrics Evaluation
# ...
# Dropdown(description='q1A:', layout=Layout(width='750px'), options=('Full marks. For correct method/implementa…
# Dropdown(description='q1B:', layout=Layout(width='750px'), options=('Full marks. For correct method/implementa…
# Dropdown(description='q1C:', layout=Layout(width='750px'), options=('Full marks. For correct method/implementa…
# Dropdown(description='q1D:', layout=Layout(width='750px'), options=('Full marks. For correct method/implementa…
# Dropdown(description='q1E:', layout=Layout(width='750px'), options=('Full marks. For correct method/implementa…
# Dropdown(description='q1F:', layout=Layout(width='750px'), options=('Full marks. For correct method/implementa…
# Dropdown(description='q1G:', layout=Layout(width='750px'), options=('Full marks. For correct method/implementa…
# Dropdown(description='q1H:', layout=Layout(width='750px'), options=('Full marks. For correct method/implementa…
# ...
# PART 2 Rubrics Evaluation
# ...

# %%
# Display Button To Calculate
display(calculate_button)
display(output)
# Out:
# Button(button_style='success', description='Calculate Total Score', icon='calculator', style=ButtonStyle())
# Output()
